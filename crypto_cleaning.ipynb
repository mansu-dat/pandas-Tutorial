# %%
import pandas as pd

# %%
crypto_df= pd.read_csv("./Crypto.csv")

# %%
crypto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21347 entries, 0 to 21346
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               21347 non-null  object
#  1   abbr               21347 non-null  object
#  2   Crypturl           21347 non-null  object
#  3   Price              21347 non-null  float64
#  4   Volume24hrs        21347 non-null  float64
#  5   marketcap          21347 non-null  object
#  6   Circulatingsupply  21347 non-null  float64
#  7   Maxsupply          21347 non-null  float64
#  8   Totalsupply        21347 non-null  float64
#  9   Date_taken         21347 non-null  object
# dtypes: float64(5), object(5)
# memory usage: 1.6+ MB

# %%
crypto_df.head(12)
# Out:
#          name     abbr                            Crypturl         Price  \
# 0     Bitcoin      BTC    https://crypto.com/price/bitcoin  62732.670000
# 1    Ethereum      ETH   https://crypto.com/price/ethereum   3027.220000
# 2      Tether     USDT     https://crypto.com/price/tether      0.999900
# 3         BNB      BNB        https://crypto.com/price/bnb    593.850000
# 4      Solana      SOL     https://crypto.com/price/solana    152.590000
# 5    USD Coin     USDC   https://crypto.com/price/usd-coin      1.000000
# 6         XRP      XRP        https://crypto.com/price/xrp      0.517300
# 7     Toncoin  TONCOIN    https://crypto.com/price/toncoin      6.640000
# 8    Dogecoin     DOGE   https://crypto.com/price/dogecoin      0.150900
# 9     Cardano      ADA    https://crypto.com/price/cardano      0.464300
# 10  Shiba Inu     SHIB  https://crypto.com/price/shiba-inu      0.000023
# 11  Avalanche     AVAX  https://crypto.com/price/avalanche     35.560000
#
# ...

# %%
crypto_df.dtypes
# Out:
# name                  object
# abbr                  object
# Crypturl              object
# Price                float64
# Volume24hrs          float64
# marketcap             object
# Circulatingsupply    float64
# Maxsupply            float64
# Totalsupply          float64
# Date_taken            object
# dtype: object

# %%
crypto_df.describe()
# Out:
#               Price    Volume24hrs  Circulatingsupply     Maxsupply  \
# count  2.134700e+04   21347.000000       2.134700e+04  2.134700e+04
# mean   7.524758e+04  488514.745820       2.109302e+06  5.000418e+08
# std    1.092127e+07  283506.240054       1.225969e+06  2.876037e+08
# min    0.000000e+00     103.983721       1.669758e+02  2.041145e+04
# 25%    1.000000e-05  241306.259550       1.041184e+06  2.518438e+08
# 50%    9.548000e-04  487505.451700       2.103832e+06  5.013132e+08
# 75%    3.687500e-02  733224.487850       3.163273e+06  7.469720e+08
# max    1.595659e+09  981555.184500       4.251433e+06  9.989293e+08
#
#         Totalsupply
# count  2.134700e+04
# mean   5.005749e+08
# std    2.893756e+08
# min    5.213366e+04
# 25%    2.498050e+08
# 50%    5.028731e+08
# 75%    7.507950e+08
# max    9.999478e+08

# %%
crypto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21347 entries, 0 to 21346
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               21347 non-null  object
#  1   abbr               21347 non-null  object
#  2   Crypturl           21347 non-null  object
#  3   Price              21347 non-null  float64
#  4   Volume24hrs        21347 non-null  float64
#  5   marketcap          21347 non-null  object
#  6   Circulatingsupply  21347 non-null  float64
#  7   Maxsupply          21347 non-null  float64
#  8   Totalsupply        21347 non-null  float64
#  9   Date_taken         21347 non-null  object
# dtypes: float64(5), object(5)
# memory usage: 1.6+ MB

# %%
crypto_df['name'].unique()
# Out:
# array(['Bitcoin', 'Ethereum', 'Tether', ..., '四皇 - Four Emperors',
#        '忠 LOYAL', '无条件为你'], dtype=object)

# %%
crypto_df['Circulatingsupply'].unique()
# Out:
# array([3065439.414 , 2326223.601 , 2207000.323 , ..., 1397511.608 ,
#        2122168.661 ,  310870.8302])

# %%
crypto_df.tail()
# Out:
#                      name     abbr  \
# 21342                  ぺぺ       ぺぺ
# 21343               喵喵喵喵喵    喵喵喵喵喵
# 21344  四皇 - Four Emperors    YONKŌ
# 21345             忠 LOYAL  LOYAL 忠
# 21346               无条件为你    无条件为你
#
#                                          Crypturl         Price  Volume24hrs  \
# 21342           https://crypto.com/price/pepe-eth  8.870000e-11  781384.1263
# 21343  https://crypto.com/price/miaomiaomiaoerc20  8.500000e-07  120877.9300
# 21344      https://crypto.com/price/four-emperors  7.988930e+03  431924.5009
# 21345              https://crypto.com/price/loyal  1.875000e-05  238668.9598
# 21346              https://crypto.com/price/wtjwn  4.900000e-08  441316.8639
#
#          marketcap  Circulatingsupply    Maxsupply  Totalsupply  Date_taken
# 21342  3,11,061.69       2.962194e+06  552536338.4  305845288.5  01/09/2015
# 21343  7,33,230.16       3.026933e+06  930507777.8  287947911.6  05/02/2000
# ...

# %%
crypto_df.drop_duplicates('Crypturl')
# Out:
#                      name     abbr  \
# 0                 Bitcoin      BTC
# 1                Ethereum      ETH
# 2                  Tether     USDT
# 3                     BNB      BNB
# 4                  Solana      SOL
# ...                   ...      ...
# 21342                  ぺぺ       ぺぺ
# 21343               喵喵喵喵喵    喵喵喵喵喵
# 21344  四皇 - Four Emperors    YONKŌ
# 21345             忠 LOYAL  LOYAL 忠
# 21346               无条件为你    无条件为你
#
#                                          Crypturl         Price  Volume24hrs  \
# 0                https://crypto.com/price/bitcoin  6.273267e+04  272076.9766
# 1               https://crypto.com/price/ethereum  3.027220e+03  981408.7883
# 2                 https://crypto.com/price/tether  9.999000e-01  944792.0394
# 3                    https://crypto.com/price/bnb  5.938500e+02  556334.5330
# 4                 https://crypto.com/price/solana  1.525900e+02  866929.0575
# ...

# %%
crypto_df['Price'].unique()
# Out:
# array([6.273267e+04, 3.027220e+03, 9.999000e-01, ..., 7.988930e+03,
#        1.875000e-05, 4.900000e-08])

# %%
crypto_df['Price']=crypto_df['Price'].replace('6.273267e+04','62732.67')

# %%
crypto_df
# Out:
#                      name     abbr  \
# 0                 Bitcoin      BTC
# 1                Ethereum      ETH
# 2                  Tether     USDT
# 3                     BNB      BNB
# 4                  Solana      SOL
# ...                   ...      ...
# 21342                  ぺぺ       ぺぺ
# 21343               喵喵喵喵喵    喵喵喵喵喵
# 21344  四皇 - Four Emperors    YONKŌ
# 21345             忠 LOYAL  LOYAL 忠
# 21346               无条件为你    无条件为你
#
#                                          Crypturl         Price  Volume24hrs  \
# 0                https://crypto.com/price/bitcoin  6.273267e+04  272076.9766
# 1               https://crypto.com/price/ethereum  3.027220e+03  981408.7883
# 2                 https://crypto.com/price/tether  9.999000e-01  944792.0394
# 3                    https://crypto.com/price/bnb  5.938500e+02  556334.5330
# 4                 https://crypto.com/price/solana  1.525900e+02  866929.0575
# ...

# %%
crypto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21347 entries, 0 to 21346
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               21347 non-null  object
#  1   abbr               21347 non-null  object
#  2   Crypturl           21347 non-null  object
#  3   Price              21347 non-null  float64
#  4   Volume24hrs        21347 non-null  float64
#  5   marketcap          21347 non-null  object
#  6   Circulatingsupply  21347 non-null  float64
#  7   Maxsupply          21347 non-null  float64
#  8   Totalsupply        21347 non-null  float64
#  9   Date_taken         21347 non-null  object
# dtypes: float64(5), object(5)
# memory usage: 1.6+ MB

# %%
crypto_df['Price'].sum()
# Out:
# 1606310016.1465113

# %%
grouped = crypto_df.groupby(['name','Price']).size()

# %%
grouped
# Out:
# name                Price
#  Alpha Venture DAO  1.115000e-01    1
# #MetaHash           1.066000e-03    1
# $AAPL               1.768000e-01    1
# $BABY PEPE COIN     1.670000e-11    1
# $CROOGE             2.220000e-06    1
#                                    ..
# ぺぺ                  8.870000e-11    1
# 喵喵喵喵喵               8.500000e-07    1
# 四皇 - Four Emperors  7.988930e+03    1
# 忠 LOYAL             1.875000e-05    1
# 无条件为你               4.900000e-08    1
# Length: 21343, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
plt.title("Various Prices")
plt.hist(crypto_df.Price);
