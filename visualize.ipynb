# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples);

# %%
plt.figure(figsize=(8,4))
x = [1,2,3,4]
y= [1,4,8,10]
plt.plot(x,y, 'or')
plt.title('line chart');

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yield_apples);

# %%
plt.plot(years, yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
plt.figure(figsize=(6,4))
plt.plot(years, yield_apples, 'or')
plt.title("yield_apples(ton per hectre)");

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]
pineapple = [0.952, 0.942, 0.335, 0.943, 0.938, 0.918, 0.908, 0.905, 0.902, 0.998, 0.8, 0.886, ]

# %%
plt.plot(years, apples)
plt.plot(years, oranges,)
plt.plot(years,pineapple)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

# %%
plt.plot(years, apples)
plt.plot(years, oranges)

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
plt.figure(figsize=(6, 4))
plt.plot(years,apples, oranges, 'or')
plt.title("Yield of Oranges,Apples (tons per hectare)")
plt.legend(['apples', 'Oranges']);

# %%
plt.plot(years, apples)
plt.plot(years, oranges,)
plt.plot(years,pineapple)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title("Crop yield in Kanto")
plt.legend(['Apples', 'Oranges', 'pineapple']);

# %%
plt.plot(years, apples, marker='o', c= 'red')
plt.plot(years, oranges, marker= '*', ls='-')
plt.plot(years,pineapple, marker='x')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title("Crop yield in Kanto")
plt.legend(['Apples', 'Oranges', 'pineapple']);

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
plt.figure(figsize=(6, 4))
plt.plot(years, apples, marker='o', c= 'red')
plt.plot(years, oranges, marker= '*', ls='-')
plt.plot(years,pineapple, marker='x')
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')
plt.title("Crop yield in Kanto")
plt.legend(['Apples', 'Oranges', 'pineapple']);

# %%
sns.set_style("darkgrid") # can change whitegrid with Darkgrid

# %%
titanic =sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic=titanic.dropna(subset=['embarked','age'])

# %%
titanic['age'] = titanic['age'].astype(int)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    int32
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    category
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  712 non-null    object
#  13  alive        712 non-null    object
#  14  alone        712 non-null    bool
# dtypes: bool(2), category(2), float64(1), int32(1), int64(4), object(5)
# memory usage: 67.2+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex  age  sibsp  parch     fare embarked  class  \
# 0         0       3    male   22      1      0   7.2500        S  Third
# 1         1       1  female   38      1      0  71.2833        C  First
# 2         1       3  female   26      0      0   7.9250        S  Third
# 3         1       1  female   35      1      0  53.1000        S  First
# 4         0       3    male   35      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
grouped = titanic.groupby(['age','embarked']).size().unstack(fill_value = 0)

# %%
grouped
# Out:
# embarked  C  Q  S
# age
# 0         3  0  4
# 1         2  0  5
# 2         0  1  9
# 3         1  0  5
# 4         1  1  8
# ..       .. .. ..
# 66        0  0  1
# 70        0  1  2
# 71        2  0  0
# 74        0  0  1
# 80        0  0  1
#
# [71 rows x 3 columns]

# %%
grouped.plot(kind='line', ls='dashed', figsize=(12,6))
plt.title('Numbers of Passenger by Age and Embarkation')
plt.xlabel =('Age')
plt.ylabel = ('Number of Passenger')
plt.legend(title = 'Embarkation port',labels=['Cherbourg (C)', 'Queenstown (Q)', 'Southampton (S)']);

# %%
titanic=titanic.dropna(subset=['sex'])

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     712 non-null    int64
#  1   pclass       712 non-null    int64
#  2   sex          712 non-null    object
#  3   age          712 non-null    int32
#  4   sibsp        712 non-null    int64
#  5   parch        712 non-null    int64
#  6   fare         712 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        712 non-null    category
#  9   who          712 non-null    object
#  10  adult_male   712 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  712 non-null    object
#  13  alive        712 non-null    object
#  14  alone        712 non-null    bool
# dtypes: bool(2), category(2), float64(1), int32(1), int64(4), object(5)
# memory usage: 67.2+ KB

# %%
grouped = titanic.groupby(['sex', 'class']).size().unstack(fill_value = 0)

# %%
grouped
# Out:
# class   First  Second  Third
# sex
# female     83      74    102
# male      101      99    253

# %%
sns.set_style("darkgrid")
grouped.plot(kind='line', ls='dashed', figsize=(6,4))
plt.title('Numbers of Males & Females')
plt.xlabel =("First")
plt.ylabel = ('Second')
plt.zlabel = ('Third')
plt.title( 'Numbers of males&females')
plt.legend(['First', 'Second', 'Third']);

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.sepal_length, flowers_df.sepal_width);

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=100);

# %%
plt.figure(figsize=(12, 6))
plt.title('Sepal Dimensions')

sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species,
                s=100);

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x=flowers_df.petal_length, y=flowers_df.petal_width, hue=flowers_df.species, s=100);

# %%
plt.figure(figsize=(12, 6))
plt.title('Petal Dimensions')

sns.scatterplot(x=flowers_df.petal_length, 
                y=flowers_df.petal_width, 
                hue=flowers_df.species,
                s=100);

# %%
plt.figure(figsize=(12,6))
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=100,
                data=flowers_df);

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width);

# %%
flowers_df['sepal_width'].value_counts()
# Out:
# sepal_width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
# Specifying the number of bins
plt.figure(figsize=(12,6))
plt.hist(flowers_df.sepal_width, bins=23);

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
setosa_df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
plt.hist(setosa_df.sepal_width, alpha=0.4);
plt.hist(versicolor_df.sepal_width, alpha=0.4);
plt.hist(virginica_df.sepal_width, alpha=0.4);

# %%
plt.title('Distribution of Sepal Width')

plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],stacked=True, bins =23);

plt.legend(['Setosa', 'Versicolor', 'Virginica']);

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, oranges);

# %% [markdown]
# ##### Like histograms, we can stack bars on top of one another. We use the bottom argument of plt.bar to achieve this.

# %%
plt.bar(years, apples)
plt.bar(years, oranges, bottom=apples)
plt.legend(['apples', 'oranges']);

# %% [markdown]
# Bar Plots with Averages

# %% [markdown]
# Let's look at another sample dataset included with Seaborn, called tips. The dataset contains information about the sex, time of day, total bill, and tip amount for customers visiting a restaurant over a week.

# %%
import seaborn as sns

# %%
tips_df = sns.load_dataset("tips");

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Calculate the average bill amount for each day of the week
avg_bill_per_day = tips_df.groupby('day')['total_bill'].mean().reindex(
    ['Sun', 'Sat', 'Thur'])

# %%
avg_bill_per_day
# Out:
# day
# Sun     21.410000
# Sat     20.441379
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
plt.figure(figsize=(10, 6))
avg_bill_per_day.plot(kind='bar', color='skyblue')
plt.title('Average Bill Amount by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Bill Amount')
plt.xticks(rotation=45)
plt.grid(axis='y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 4
#       2 avg_bill_per_day.plot(kind='bar', color='skyblue')
#       3 plt.title('Average Bill Amount by Day of the Week')
# ----> 4 plt.xlabel('Day of the Week')
#       5 plt.ylabel('Average Bill Amount')
#       6 plt.xticks(rotation=45)
#
# TypeError: 'str' object is not callable

# %%
sns.barplot(x='day', y='total_bill', data=tips_df);

# %%
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);

# %%
# You can make the bars horizontal simply by switching the axes.
sns.barplot(x='total_bill', y='day', hue='sex', data=tips_df);

# %%
pip install jovian
# Out:
# ...
#   Obtaining dependency information for jovian from https://files.pythonhosted.org/packages/8a/17/0cf36225a66e2c20bcda2b60d5003aa69443294030049c0f75c0e9cc877d/jovian-0.2.47-py2.py3-none-any.whl.metadata
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/68.6 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/68.6 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/68.6 kB ? eta -:--:--
#    ----------------------------------- ---- 61.4/68.6 kB 409.6 kB/s eta 0:00:01
#    ---------------------------------------- 68.6/68.6 kB 339.4 kB/s eta 0:00:00
# ...
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6484 sha256=77b93ac8744988126584b38fad85fc939b54b4c1fe237686a62ab4257d013b19
#   Stored in directory: c:\users\user-pc\appdata\local\pip\cache\wheels\e0\01\df\bd20df409bd81f8b99e6cd343c5f49731dc0a20eefefdafae0
# Successfully built uuid
# ...

# %%
import jovian

# %%
jovian.commit(filename= 'my-notebook.ipynb')
# Out:
# [jovian] Error: Failed to read the Jupyter notebook. Please re-run this cell to try again. If the issue persists, provide the "filename" argument to "jovian.commit" e.g. "jovian.commit(filename='my-notebook.ipynb')"

# %%
import seaborn as sns

# %%
flights_df = sns.load_dataset("flights")

# %%
flights_df = flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 flights_df = flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 4 were given

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.plot(kind='line', x='embark_town', y='age');

# %%
grouped = titanic.groupby(['class','who']).size().unstack(fill_value = 0)

# %%
grouped
# Out:
# who     child  man  woman
# class
# First       6  119     91
# Second     19   99     66
# Third      58  319    114

# %%
grouped.plot(kind='line', ls='dashed', figsize=(6,4))
plt.title('Numbers of Passenger by Embarktion and Age')
plt.xlabel =('age')
plt.ylabel = ('Number of Passenger')
plt.legend(title = 'Embarkation port',labels=['Child (C)', 'Man (M)', 'Woman (W)']);

# %%
titanic.survived
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
plt.title("The Ages in Titanic")
plt.hist(titanic.age);

# %%
titanic =sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(x=titanic.sibsp, y=titanic.parch, );

# %%
sns.scatterplot(x=titanic.parch, y=titanic.sibsp,s=100)
plt.legend(['sibsp', 'parch']);
