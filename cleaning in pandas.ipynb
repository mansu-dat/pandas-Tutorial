# %%
import pandas as pd

# %%
df = pd.read_csv('.//ebay_womens_perfume.csv')

# %%
df
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df.isnull()
# Out:
#      brand  title   type  price  priceWithCurrency  available  availableText  \
# 0    False  False  False  False              False      False          False
# 1    False  False  False  False              False      False          False
# 2    False  False  False  False              False      False          False
# 3    False  False  False  False              False      False          False
# 4    False  False  False  False              False      False          False
# ..     ...    ...    ...    ...                ...        ...            ...
# 995  False  False  False  False              False      False          False
# 996  False  False  False  False              False      False          False
# 997  False  False  False  False              False      False          False
# 998  False  False  False  False              False      False          False
# 999  False  False  False  False              False      False          False
#
#       sold  lastUpdated  itemLocation
# ...

# %%
df.dropna(axis=1)
# Out:
#                                                  title  price  \
# 0    Good Girl by Carolina Herrera 2.7 oz Eau De Pa...  43.99
# 1    Parfums de Marly Delina La Rosee Eau de Parfum...  79.99
# 2    PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...  59.99
# 3    J'adore Parfum D'eau by Christian 3.4 oz EDP F...  59.99
# 4    Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...  29.99
# ..                                                 ...    ...
# 995  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...  13.89
# 996  Roses Greedy by Mancera perfume for unisex EDP...  57.85
# 997  Sweet Tooth Eau de Parfum, Perfume for Women, ...  30.96
# 998  MMMM BY Juliette Has A Gun perfume for her EDP...  53.99
# 999  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...  14.99
#
#     priceWithCurrency                             itemLocation
# 0        US $43.99/ea      Thomasville, Alabama, United States
# 1           US $79.99                    New Jersey, Hong Kong
# ...

# %%
df.dropna(how ='all', axis=0)# what in () can be subtitued
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df.dropna(thresh=7)
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df.fillna(0)# () can be rplce 'empty', 'babo'
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df.fillna(method='ffill')# ()'bfill
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df['sold'].fillna(df['sold'].min())
# Out:
# 0      393.0
# 1       40.0
# 2       35.0
# 3        9.0
# 4        1.0
#        ...
# 995    157.0
# 996     58.0
# 997      3.0
# 998    117.0
# 999     51.0
# Name: sold, Length: 1000, dtype: float64

# %%
df.duplicated().value_counts()
# Out:
# False    999
# True       1
# Name: count, dtype: int64

# %%
df.duplicated(['title', 'type']).value_counts()
# Out:
# False    975
# True      25
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#       brand                                              title     type  \
# 662  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
#
#      price priceWithCurrency  available         availableText  sold  \
# 662   48.0         US $48.00        4.0  4 available / 1 sold   1.0
#
#     lastUpdated                     itemLocation
# 662         NaN  Webster, Florida, United States

# %%
df[df['brand']=='FLOWER']
# Out:
#       brand                                              title     type  \
# 344  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
# 662  FLOWER  12 Piece Woman’s Perfume Lot: Assorted scents ...  Perfume
#
#      price priceWithCurrency  available         availableText  sold  \
# 344   48.0         US $48.00        4.0  4 available / 1 sold   1.0
# 662   48.0         US $48.00        4.0  4 available / 1 sold   1.0
#
#     lastUpdated                     itemLocation
# 344         NaN  Webster, Florida, United States
# 662         NaN  Webster, Florida, United States

# %%
df.drop_duplicates()
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
df.drop_duplicates(subset=['title', 'type'])
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
dropped = df.drop_duplicates()
dropped.iloc[660:665]
# Out:
#               brand                                              title  \
# 660             JLO  Glow by J.LO Jennifer Lopez Perfume for Women ...
# 661  Gianni Versace  Versace VERSENSE EDT for Women 3.3 / 3.4 oz Ne...
# 663  Ainash Perfums  Royal Noir Absolu by Ainash 2.5 oz Extrait de ...
# 664  Britney Spears  Curious By Britney Spears Mini EDP Splash Perf...
# 665         Lancôme  La Vie Est Belle by Lancome 3.4 oz / 100 ml Sp...
#
#                   type  price priceWithCurrency  available  \
# 660    Eau de Toilette  26.81      US $26.81/ea        NaN
# 661    Eau de Toilette  38.76      US $38.76/ea        NaN
# 663  Extrait de Parfum  58.50         US $58.50       10.0
# 664      Eau de Parfum  10.99      US $10.99/ea        8.0
# 665      Eau de Parfum  42.99      US $42.99/ea        2.0
#
#                              availableText   sold                lastUpdated  \
# 660  Limited quantity available / 478 sold  478.0  May 24, 2024 09:37:10 PDT
# ...

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['brand', 'title', 'type', 'price', 'pricinCurrency', 'available',
#        'availableText', 'sold', 'Location', 'lastUpdated'],
#       dtype='object')>

# %%
df.columns=['brand', 'title', 'type', 'price', 'pricinCurrency', 'available',
       'availableText', 'sold','Location', 'lastUpdated']

# %%
df
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price pricinCurrency  available  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           999 non-null    object
#  1   title           1000 non-null   object
#  2   type            998 non-null    object
#  3   price           1000 non-null   float64
#  4   pricinCurrency  1000 non-null   object
#  5   available       1000 non-null   float64
#  6   availableText   992 non-null    object
#  7   sold            1000 non-null   float64
#  8   Location        927 non-null    object
#  9   lastUpdated     1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
df['available'].fillna(0, inplace=True)

# %%
df['sold'].fillna(0, inplace=True)
df['sold'].astype('int')
# Out:
# 0      393
# 1       40
# 2       35
# 3        9
# 4        0
#       ...
# 995    157
# 996     58
# 997      3
# 998    117
# 999     51
# Name: sold, Length: 1000, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           999 non-null    object
#  1   title           1000 non-null   object
#  2   type            998 non-null    object
#  3   price           1000 non-null   float64
#  4   pricinCurrency  1000 non-null   object
#  5   available       1000 non-null   float64
#  6   availableText   992 non-null    object
#  7   sold            1000 non-null   float64
#  8   Location        927 non-null    object
#  9   lastUpdated     1000 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 78.3+ KB

# %%
df['lastUpdated'].ffill(inplace=True)

# %%
df['title'].str.strip()
# Out:
# 0      Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1      Parfums de Marly Delina La Rosee Eau de Parfum...
# 2      PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3      J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4      Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
#                              ...
# 995    Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996    Roses Greedy by Mancera perfume for unisex EDP...
# 997    Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998    MMMM BY Juliette Has A Gun perfume for her EDP...
# 999    PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
# Name: title, Length: 1000, dtype: object

# %%
cleaning_df = pd.read_excel('./Data Cleaning Excel Tutorial.xlsx')

# %%
cleaning_df
# Out:
#     Unnamed: 0  S.No.               president  \
# 0            0      1       George Washington
# 1            1      2              john adams
# 2            2      3        Thomas Jefferson
# 3            3      4           James Madison
# 4            4      5            JAMES MONROE
# 5            5      6       John Quincy Adams
# 6            6      7          Andrew Jackson
# 7            7      8        Martin Van Buren
# 8            8      9  William Henry Harrison
# 9            9     10              john tyler
# 10          10     11           James K. Polk
# 11          11     12          Zachary Taylor
# 12          12     13        Millard Fillmore
# 13          13     14         Franklin Pierce
# 14          14     15          James Buchanan
# 15          15     16         Abraham Lincoln
# 16          16     17          Andrew Johnson
# 17          17     18        Ulysses S. Grant
# 18          18     19     Rutherford B. Hayes
# ...

# %%
cleaning_df.columns
# Out:
# Index(['Unnamed: 0', 'S.No.', 'president', 'prior', 'party', 'vice', 'salary',
#        'date updated', 'date created'],
#       dtype='object')

# %%
cleaning_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
cleaning_df
# Out:
#     S.No.               president  \
# 0       1       George Washington
# 1       2              john adams
# 2       3        Thomas Jefferson
# 3       4           James Madison
# 4       5            JAMES MONROE
# 5       6       John Quincy Adams
# 6       7          Andrew Jackson
# 7       8        Martin Van Buren
# 8       9  William Henry Harrison
# 9      10              john tyler
# 10     11           James K. Polk
# 11     12          Zachary Taylor
# 12     13        Millard Fillmore
# 13     14         Franklin Pierce
# 14     15          James Buchanan
# 15     16         Abraham Lincoln
# 16     17          Andrew Johnson
# 17     18        Ulysses S. Grant
# 18     19     Rutherford B. Hayes
# 19     20       James A. Garfield
# 20     21       Chester A. Arthur
# 21     22        Grover Cleveland
# 22     23       Benjamin Harrison
# 23     24        Grover Cleveland
# 24     25        William McKinley
# 25     26      Theodore Roosevelt
# ...

# %%
cleaning_df.columns = ['S.No.', 'President', 'Prior', 'Party', 'Vice', 'Salary',
       'Date updated', 'Date created']

# %%
cleaning_df
# Out:
#     S.No.               President  \
# 0       1       George Washington
# 1       2              john adams
# 2       3        Thomas Jefferson
# 3       4           James Madison
# 4       5            JAMES MONROE
# 5       6       John Quincy Adams
# 6       7          Andrew Jackson
# 7       8        Martin Van Buren
# 8       9  William Henry Harrison
# 9      10              john tyler
# 10     11           James K. Polk
# 11     12          Zachary Taylor
# 12     13        Millard Fillmore
# 13     14         Franklin Pierce
# 14     15          James Buchanan
# 15     16         Abraham Lincoln
# 16     17          Andrew Johnson
# 17     18        Ulysses S. Grant
# 18     19     Rutherford B. Hayes
# 19     20       James A. Garfield
# 20     21       Chester A. Arthur
# 21     22        Grover Cleveland
# 22     23       Benjamin Harrison
# 23     24        Grover Cleveland
# 24     25        William McKinley
# 25     26      Theodore Roosevelt
# ...

# %%
cleaning_df['President'].str.strip()
# Out:
# 0          George Washington
# 1                 john adams
# 2           Thomas Jefferson
# 3              James Madison
# 4               JAMES MONROE
# 5          John Quincy Adams
# 6             Andrew Jackson
# 7           Martin Van Buren
# 8     William Henry Harrison
# 9                 john tyler
# 10             James K. Polk
# 11            Zachary Taylor
# 12          Millard Fillmore
# 13           Franklin Pierce
# 14            James Buchanan
# 15           Abraham Lincoln
# 16            Andrew Johnson
# 17          Ulysses S. Grant
# 18       Rutherford B. Hayes
# 19         James A. Garfield
# 20         Chester A. Arthur
# 21          Grover Cleveland
# 22         Benjamin Harrison
# 23          Grover Cleveland
# 24          William McKinley
# 25        Theodore Roosevelt
# 26       William Howard Taft
# 27            Woodrow Wilson
# 28            Woodrow Wilson
# 29         Warren G. Harding
# 30           Calvin Coolidge
# 31            Herbert Hoover
# ...

# %%
cleaning_df = cleaning_df['President'].str.upper()

# %%
cleaning_df
# Out:
# 0          GEORGE WASHINGTON
# 1                 JOHN ADAMS
# 2           THOMAS JEFFERSON
# 3              JAMES MADISON
# 4               JAMES MONROE
# 5          JOHN QUINCY ADAMS
# 6             ANDREW JACKSON
# 7           MARTIN VAN BUREN
# 8     WILLIAM HENRY HARRISON
# 9                 JOHN TYLER
# 10             JAMES K. POLK
# 11            ZACHARY TAYLOR
# 12          MILLARD FILLMORE
# 13           FRANKLIN PIERCE
# 14            JAMES BUCHANAN
# 15           ABRAHAM LINCOLN
# 16            ANDREW JOHNSON
# 17          ULYSSES S. GRANT
# 18       RUTHERFORD B. HAYES
# 19         JAMES A. GARFIELD
# 20         CHESTER A. ARTHUR
# 21          GROVER CLEVELAND
# 22         BENJAMIN HARRISON
# 23          GROVER CLEVELAND
# 24          WILLIAM MCKINLEY
# 25        THEODORE ROOSEVELT
# 26       WILLIAM HOWARD TAFT
# 27            WOODROW WILSON
# 28            WOODROW WILSON
# 29         WARREN G. HARDING
# 30           CALVIN COOLIDGE
# 31            HERBERT HOOVER
# ...
