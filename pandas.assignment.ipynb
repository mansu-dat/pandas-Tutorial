# %%
#1. Selecting Columns:
#Select the 'Name' and 'Survived' columns from the Titanic dataset.

# %%
import pandas as pd

# %%
tested_df = pd.read_csv("./tested.csv")

# %%
tested_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tested_df =tested_df[['Name','Survived']]

# %%
tested_df
# Out:
#                                              Name  Survived
# 0                                Kelly, Mr. James         0
# 1                Wilkes, Mrs. James (Ellen Needs)         1
# 2                       Myles, Mr. Thomas Francis         0
# 3                                Wirz, Mr. Albert         0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1
# ..                                            ...       ...
# 413                            Spector, Mr. Woolf         0
# 414                  Oliva y Ocana, Dona. Fermina         1
# 415                  Saether, Mr. Simon Sivertsen         0
# 416                           Ware, Mr. Frederick         0
# 417                      Peter, Master. Michael J         0
#
# [418 rows x 2 columns]

# %%
#2. Indexing Rows by Position:
#Select the first five rows of the DataFrame.

# %%
tested_df = tested_df.iloc[0:5]

# %%
tested_df
# Out:
#                                            Name  Survived
# 0                              Kelly, Mr. James         0
# 1              Wilkes, Mrs. James (Ellen Needs)         1
# 2                     Myles, Mr. Thomas Francis         0
# 3                              Wirz, Mr. Albert         0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1

# %%
#3. Indexing Rows by Label:- Select the rows where the index labels are 1 and 3.

# %%
tested_df = tested_df.loc[1]

# %%
tested_df
# Out:
# PassengerId                                 893
# Survived                                      1
# Pclass                                        3
# Name           Wilkes, Mrs. James (Ellen Needs)
# Sex                                      female
# Age                                        47.0
# SibSp                                         1
# Parch                                         0
# Ticket                                   363272
# Fare                                        7.0
# Cabin                                       NaN
# Embarked                                      S
# Name: 1, dtype: object

# %%
tested_df = tested_df.loc[3]

# %%
tested_df
# Out:
# PassengerId                 895
# Survived                      0
# Pclass                        3
# Name           Wirz, Mr. Albert
# Sex                        male
# Age                        27.0
# SibSp                         0
# Parch                         0
# Ticket                   315154
# Fare                     8.6625
# Cabin                       NaN
# Embarked                      S
# Name: 3, dtype: object

# %%
#4.Filtering Rows:
#- Filter the rows where the 'Age' is greater than 30.

# %%
tested_df = tested_df['Age']> 30.0

# %%
tested_df
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415     True
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
#5.Multiple Conditions:
#- Filter the rows where 'Age' is greater than 30 and 'Pclass' is 1.

# %%
tested_df[(tested_df['Age'] > 30.0) & (tested_df['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 14           906         1       1
# 20           912         0       1
# 24           916         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 397         1289         1       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#6.Assigning New Values:
#-Increase the 'Fare' by 10 for all rows where 'Age' is less than 10.

# %%
tested_df.loc[tested_df['Age']<10,'Fare'] +=10

# %%
tested_df.loc[tested_df['Age']<10]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 21           913         0       3                Olsen, Master. Artur Karl
# 80           972         0       3                     Boulos, Master. Akar
# 89           981         0       2              Wells, Master. Ralph Lester
# 117         1009         1       3          Sandstrom, Miss. Beatrice Irene
# 161         1053         0       3           Touma, Master. Georges Youssef
# 194         1086         0       2            Drew, Master. Marshall Brines
# 196         1088         0       1          Spedden, Master. Robert Douglas
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 203         1095         1       2               Quick, Miss. Winifred Vera
# 250         1142         1       2                    West, Miss. Barbara J
# 263         1155         1       3             Klasen, Miss. Gertrud Emilia
# ...

# %%
#7. Adding a New Column:
#- Add a new column 'FamilySize' that contains the sum of 'SibSp' and 'Parch' plus 1 (to include the passenger).

# %%
tested_df ['FamilySize'] = tested_df['SibSp'] + tested_df['Parch']+1

# %%
tested_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tested_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
