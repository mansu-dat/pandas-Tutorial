# %%
import pandas as pd

# %%
student = {'name':['John','Anna','Peter','Linda'],
           'Age':[28,24,25,32],
           'Cities':['Boston','Austin','Denver','Seattle']
}
student_df = pd.DataFrame(student)

# %%
student_df
# Out:
#     name  Age   Cities
# 0   John   28   Boston
# 1   Anna   24   Austin
# 2  Peter   25   Denver
# 3  Linda   32  Seattle

# %%
student_df.to_csv('student.csv')

# %%
student_df.to_excel('student.xlsx')

# %%
student_df = pd.read_csv('./student.csv')

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities
# 0           0   John   28   Boston
# 1           1   Anna   24   Austin
# 2           2  Peter   25   Denver
# 3           3  Linda   32  Seattle

# %%
student_df.to_json('./student.json')

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities
# 0           0   John   28   Boston
# 1           1   Anna   24   Austin
# 2           2  Peter   25   Denver
# 3           3  Linda   32  Seattle

# %%
# INDEXING

# %%
import pandas as pd

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities
# 0           0   John   28   Boston
# 1           1   Anna   24   Austin
# 2           2  Peter   25   Denver
# 3           3  Linda   32  Seattle

# %%
student_df['Complextion'] = ['Fair','Black','Chocolate','Dark']

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities Complextion
# 0           0   John   28   Boston        Fair
# 1           1   Anna   24   Austin       Black
# 2           2  Peter   25   Denver   Chocolate
# 3           3  Linda   32  Seattle        Dark

# %%
student_df['Age'] = student_df['Age']+1

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities Complextion
# 0           0   John   29   Boston        Fair
# 1           1   Anna   25   Austin       Black
# 2           2  Peter   26   Denver   Chocolate
# 3           3  Linda   33  Seattle        Dark

# %%
student_df['Age'][0] = 30
# Out:
# C:\Users\USER-PC\AppData\Local\Temp\ipykernel_13948\86259277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_df['Age'][0] = 30

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities Complextion
# 0           0   John   30   Boston        Fair
# 1           1   Anna   25   Austin       Black
# 2           2  Peter   26   Denver   Chocolate
# 3           3  Linda   33  Seattle        Dark

# %%
student_df["Score"][2] = 50
# Out:
# C:\Users\USER-PC\AppData\Local\Temp\ipykernel_13948\853631372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   student_df["Score"][2] = 50

# %%
student_df
# Out:
#    Unnamed: 0   name  Age   Cities Complextion  Score
# 0           0   John   30   Boston        Fair     71
# 1           1   Anna   25   Austin       Black     81
# 2           2  Peter   26   Denver   Chocolate     50
# 3           3  Linda   33  Seattle        Dark     61

# %%
student_df['Pass'] = [ 80,90,76,100]
student_df
# Out:
#    Unnamed: 0   name  Age   Cities Complextion  Score  Pass
# 0           0   John   30   Boston        Fair     70    80
# 1           1   Anna   25   Austin       Black     80    90
# 2           2  Peter   26   Denver   Chocolate     45    76
# 3           3  Linda   33  Seattle        Dark     60   100

# %%
Sat_College=pd.read_csv("./SAT__College_Board__2010_School_Level_Results_20240506.csv")

# %%
Sat_College
# Out:
#         DBN                                        School Name  \
# 0    01M292     Henry Street School for International Studies
# 1    01M448               University Neighborhood High School
# 2    01M450                   East Side Community High School
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# ..      ...                                                ...
# 455  75R025                        South Richmond High School
# 456  75X012                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754  P754 X - Jeffrey M. Rapport School for Career ...
# 458  76K460                              John Jay High School
# 459  79X490                                    PHOENIX SCHOOL
#
#      Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                     31.0                  391.0             425.0
# 1                     60.0                  394.0             419.0
# ...

# %%
Sat_College.loc[455]
# Out:
# DBN                                           75R025
# School Name              South Richmond High School
# Number of Test Takers                           10.0
# Critical Reading Mean                          407.0
# Mathematics Mean                               421.0
# Writing Mean                                   400.0
# Name: 455, dtype: object

# %%
Sat_College.loc[25:30,['DBN','School Name'] ]
# Out:
#        DBN                                      School Name
# 25  02M411               Baruch College Campus High School
# 26  02M412  New York City Laboratory School Collab Studies
# 27  02M413                            SCHOOL OF THE FUTURE
# 28  02M414                     NEW YORK CITY MUSEUM SCHOOL
# 29  02M416                   ELEANOR ROOSEVELT HIGH SCHOOL
# 30  02M418                          Millennium High School

# %%
Sat_College.iloc[5:10]
# Out:
#       DBN                                   School Name  \
# 5  01M515      Lower East Side Preparatory High School
# 6  01M539  New Explorations into Sci, Tech and Math HS
# 7  01M650                         CASCADES HIGH SCHOOL
# 8  01M696               BARD HIGH SCHOOL EARLY COLLEGE
# 9  02M047                  AMERICAN SIGN LANG ENG DUAL
#
#    Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 5                  154.0                  314.0             532.0
# 6                   47.0                  568.0             583.0
# 7                   35.0                  411.0             401.0
# 8                  138.0                  630.0             608.0
# 9                   11.0                  405.0             415.0
#
#    Writing Mean
# 5         314.0
# 6         568.0
# 7         401.0
# 8         630.0
# 9         385.0

# %%
Sat_College [5:10]
# Out:
#       DBN                                   School Name  \
# 5  01M515      Lower East Side Preparatory High School
# 6  01M539  New Explorations into Sci, Tech and Math HS
# 7  01M650                         CASCADES HIGH SCHOOL
# 8  01M696               BARD HIGH SCHOOL EARLY COLLEGE
# 9  02M047                  AMERICAN SIGN LANG ENG DUAL
#
#    Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 5                  154.0                  314.0             532.0
# 6                   47.0                  568.0             583.0
# 7                   35.0                  411.0             401.0
# 8                  138.0                  630.0             608.0
# 9                   11.0                  405.0             415.0
#
#    Writing Mean
# 5         314.0
# 6         568.0
# 7         401.0
# 8         630.0
# 9         385.0

# %%
Sat_College.DBN
# Out:
# 0      01M292
# 1      01M448
# 2      01M450
# 3      01M458
# 4      01M509
#         ...
# 455    75R025
# 456    75X012
# 457    75X754
# 458    76K460
# 459    79X490
# Name: DBN, Length: 460, dtype: object

# %%
Sat_College['Mathematics Mean']
# Out:
# 0      425.0
# 1      419.0
# 2      431.0
# 3      370.0
# 4        NaN
#        ...
# 455    421.0
# 456      NaN
# 457      NaN
# 458    381.0
# 459    423.0
# Name: Mathematics Mean, Length: 460, dtype: float64

# %%
Sat_College[['DBN','Writing Mean','School Name']]
# Out:
#         DBN  Writing Mean                                        School Name
# 0    01M292         385.0     Henry Street School for International Studies
# 1    01M448         387.0               University Neighborhood High School
# 2    01M450         402.0                   East Side Community High School
# 3    01M458         378.0                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509           NaN                                  CMSP HIGH SCHOOL
# ..      ...           ...                                                ...
# 455  75R025         400.0                        South Richmond High School
# 456  75X012           NaN                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754           NaN  P754 X - Jeffrey M. Rapport School for Career ...
# 458  76K460         398.0                              John Jay High School
# 459  79X490         416.0                                    PHOENIX SCHOOL
#
# [460 rows x 3 columns]

# %%
Sat_College[Sat_College['Writing Mean'] > 400.0]
# Out:
#         DBN                                   School Name  \
# 2    01M450              East Side Community High School
# 6    01M539  New Explorations into Sci, Tech and Math HS
# 7    01M650                         CASCADES HIGH SCHOOL
# 8    01M696               BARD HIGH SCHOOL EARLY COLLEGE
# 10   02M288                  FOOD AND FNANCE HIGH SCHOOL
# ..      ...                                           ...
# 437  31R450                           CURTIS HIGH SCHOOL
# 438  31R455                      TOTTENVILLE HIGH SCHOOL
# 439  31R460                   SUSAN E WAGNER HIGH SCHOOL
# 442  31R605          STATEN ISLAND TECHNICAL HIGH SCHOOL
# 459  79X490                               PHOENIX SCHOOL
#
#      Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 2                     69.0                  418.0             431.0
# 6                     47.0                  568.0             583.0
# 7                     35.0                  411.0             401.0
# ...

# %%
Sat_College[(Sat_College['Writing Mean'] > 400.0) & (Sat_College['Mathematics Mean'] > 441.0)]
# Out:
#         DBN                                        School Name  \
# 6    01M539       New Explorations into Sci, Tech and Math HS
# 8    01M696                    BARD HIGH SCHOOL EARLY COLLEGE
# 13   02M298                                  PACE HIGH SCHOOL
# 14   02M300  Urban Assembly School of Design and Construction
# 22   02M400                     HIGH SCHOOL ENVRNMNTL STUDIES
# ..      ...                                                ...
# 435  31R440                              NEW DORP HIGH SCHOOL
# 436  31R445                         PORT RICHMOND HIGH SCHOOL
# 438  31R455                           TOTTENVILLE HIGH SCHOOL
# 439  31R460                        SUSAN E WAGNER HIGH SCHOOL
# 442  31R605               STATEN ISLAND TECHNICAL HIGH SCHOOL
#
#      Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 6                     47.0                  568.0             583.0
# 8                    138.0                  630.0             608.0
# ...

# %%
Sat_College['Bonanza Percentage'] = Sat_College['Mathematics Mean']* 0.5

# %%
Sat_College
# Out:
#         DBN                                        School Name  \
# 0    01M292     Henry Street School for International Studies
# 1    01M448               University Neighborhood High School
# 2    01M450                   East Side Community High School
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# ..      ...                                                ...
# 455  75R025                        South Richmond High School
# 456  75X012                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754  P754 X - Jeffrey M. Rapport School for Career ...
# 458  76K460                              John Jay High School
# 459  79X490                                    PHOENIX SCHOOL
#
#      Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                     31.0                  391.0             425.0
# 1                     60.0                  394.0             419.0
# ...

# %%
Sat_College ['Bonanza Price'] = Sat_College['Mathematics Mean'] - Sat_College['Bonanza Percentage']

# %%
Sat_College
# Out:
#         DBN                                        School Name  \
# 0    01M292     Henry Street School for International Studies
# 1    01M448               University Neighborhood High School
# 2    01M450                   East Side Community High School
# 3    01M458                      SATELLITE ACADEMY FORSYTH ST
# 4    01M509                                  CMSP HIGH SCHOOL
# ..      ...                                                ...
# 455  75R025                        South Richmond High School
# 456  75X012                      PS12X LEWIS AND CLARK SCHOOL
# 457  75X754  P754 X - Jeffrey M. Rapport School for Career ...
# 458  76K460                              John Jay High School
# 459  79X490                                    PHOENIX SCHOOL
#
#      Number of Test Takers  Critical Reading Mean  Mathematics Mean  \
# 0                     31.0                  391.0             425.0
# 1                     60.0                  394.0             419.0
# ...

# %%
import pandas as pd

# %%
perfume_df=pd.read_csv("./ebay_mens_perfume.csv")

# %%
perfume_df
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
perfume_df['brand'].replace('AS SHOW', 'As Show', inplace=True)

# %%
perfume_df
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           As Show  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
df = perfume_df.drop("priceWithCurrency", axis = 1)

# %%
df
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           As Show  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price  available  \
# 0      Eau de Parfum   84.99       10.0
# ...

# %%
new_df = perfume_df.drop([997, 998,999], axis = 0)

# %%
new_df
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           As Show  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 992   Mandarin Duck  Mandarina Duck Black 3.4oz EDT Spray For Men N...
# 993  Franck Olivier  Blue Touch By Franck Olivier Men Cologne 3.3oz...
# 994   Dolce&Gabbana  Dolce & Gabbana Cologne For Men Eau De Toilett...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
new_df.drop([991, 992,993], axis = 0, inplace = True)

# %%
new_df
# Out:
#                 brand                                              title  \
# 0                Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1             As Show  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2           Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3      Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4             Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..                ...                                                ...
# 989  Yves de Sistelle  Thallium Anonymous by Yves de Sistelle Cologne...
# 990       Perry Ellis  Perry Ellis 360 Red by Perry Ellis, 6.8 oz EDT...
# 994     Dolce&Gabbana  Dolce & Gabbana Cologne For Men Eau De Toilett...
# 995             GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996             Armaf  Club de Nuit Intense by Armaf cologne for men ...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
perfume_df['price'].mean()
# Out:
# 46.4812

# %%
filtered_df = perfume_df[perfume_df['available'] >10 ]

# %%
filtered_df
# Out:
#                  brand                                              title  \
# 34         Guy Laroche  DRAKKAR NOIR by Guy Laroche 3.4 oz / 3.3 oz ed...
# 35           Montblanc  MONT BLANC LEGEND 3.3 / 3.4 oz EDT Cologne for...
# 43            Givenchy  PI by Givenchy cologne for men EDT 3.3 / 3.4 o...
# 46             Lattafa  Qaed Al Fursan by Lattafa perfume for unisex E...
# 47   Polo Ralph Lauren  POLO SPORT Ralph Lauren 4.2 oz Cologne for Men...
# ..                 ...                                                ...
# 969            Lalique  Lalique by Lalique cologne for men EDP 4.2 oz ...
# 979               BRUT  Original Fragrance Cologne by Brut for Men - 5...
# 987               Cuba  Cuba Brazil By Cuba cologne for men EDT 3.3 / ...
# 989   Yves de Sistelle  Thallium Anonymous by Yves de Sistelle Cologne...
# 995              GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
#
#                 type  price priceWithCurrency  available  \
# ...

# %%
filtered_df['price'].sum()
# Out:
# 3913.4500000000007

# %%
filtered_df['price'].max()
# Out:
# 140.0

# %%
filtered_df['price'].min()
# Out:
# 3.0

# %%
perfume_df[perfume_df['price']==perfume_df['price'].max()]
# Out:
#      brand                                              title           type  \
# 218  Creed  Aventus by Creed, 3.3 oz Millesime EDP Spray f...  Eau De Parfum
#
#       price priceWithCurrency  available                      availableText  \
# 218  259.09     US $259.09/ea       10.0  More than 10 available / 456 sold
#
#       sold                lastUpdated                       itemLocation
# 218  456.0  May 24, 2024 08:34:05 PDT  Edison, New Jersey, United States

# %%
perfume_df[perfume_df['price']==perfume_df['price'].min()]
# Out:
#                      brand                                              title  \
# 778  Alexandria Fragrances  Alexandria fragrances: BLACK PANTHER INSPIRED ...
#
#               type  price priceWithCurrency  available          availableText  \
# 778  Eau de Parfum    3.0          US $3.00       39.0  39 available / 4 sold
#
#      sold                lastUpdated                            itemLocation
# 778   4.0  May 23, 2024 18:11:56 PDT  Wynnewood, Pennsylvania, United States

# %%
perfume_df.describe()
# Out:
#              price   available          sold
# count  1000.000000  889.000000    994.000000
# mean     46.481200   20.046119    766.266600
# std      35.527862   61.547985   3200.971733
# min       3.000000    2.000000      1.000000
# 25%      22.990000    5.000000     14.000000
# 50%      35.710000   10.000000     49.500000
# 75%      59.000000   10.000000    320.500000
# max     259.090000  842.000000  54052.000000

# %%
perfume_df['title'].count()
# Out:
# 1000

# %%
perfume_df['available'].count()
# Out:
# 889

# %%
perfume_df['availableText'].count()
# Out:
# 997

# %%
perfume_df['brand'].value_counts()
# Out:
# brand
# Giorgio Armani       60
# Paco Rabanne         45
# Ralph Lauren         41
# Unbranded            39
# Armaf                34
#                      ..
# Ulric de Varens       1
# KING OF KINGS         1
# MONT BLANC LEGEND     1
# Coty Inc.             1
# Estee Lauder          1
# Name: count, Length: 245, dtype: int64

# %% [markdown]
# # Print out the count of perfumes that their prices is more than the mean of the price

# %%
perfume_df [perfume_df['price'] <=perfume_df['price'].mean()].count()
# Out:
# brand                647
# title                647
# type                 645
# price                647
# priceWithCurrency    647
# available            590
# availableText        647
# sold                 644
# lastUpdated          610
# itemLocation         647
# dtype: int64

# %%
perfume_df.head()
# Out:
#             brand                                              title  \
# 0            Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1         As Show  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2       Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3  Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4         Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
#
#               type   price priceWithCurrency  available  \
# 0    Eau de Parfum   84.99      US $84.99/ea       10.0
# 1    Eau de Parfum  109.99        US $109.99        8.0
# 2  Eau de Toilette  100.00        US $100.00       10.0
# 3  Eau de Toilette   44.99      US $44.99/ea        2.0
# 4       Fragrances   16.91         US $16.91        NaN
#
#                            availableText   sold                lastUpdated  \
# 0      More than 10 available / 116 sold  116.0  May 24, 2024 10:03:04 PDT
# ...

# %%
perfume_df.tail()
# Out:
#             brand                                              title  \
# 995         GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996         Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997  Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998        Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999  Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type  price priceWithCurrency  available  \
# 995  Eau de Toilette  20.28      US $20.28/ea       45.0
# 996  Eau de Toilette  30.58         US $30.58       10.0
# 997  Eau de Toilette  39.99      US $39.99/ea        2.0
# 998  Eau de Toilette   9.99       US $9.99/ea        2.0
# 999    Cologne spray  17.49      US $17.49/ea       10.0
#
#                         availableText    sold                lastUpdated  \
# 995         45 available / 1,613 sold  1613.0  May 24, 2024 08:14:07 PDT
# ...

# %%
perfume_df.dtypes
# Out:
# brand                 object
# title                 object
# type                  object
# price                float64
# priceWithCurrency     object
# available            float64
# availableText         object
# sold                 float64
# lastUpdated           object
# itemLocation          object
# dtype: object
