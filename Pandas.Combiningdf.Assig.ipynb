# %%
#1.Load the Titanic dataset
import pandas as pd

# %%
Titanic_df = pd.read_csv("Titanic.csv")

# %%
Titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#2.Create two DataFrames:
#- `passengers` with columns: `PassengerId`, `Name`, `Sex`
#- `tickets` with columns: `PassengerId`, `Ticket`, `Fare`

# %%
import pandas as pd

# %%
Passenger_Data = { 'PassengerId':[123],
                  'Name':['kola'],
                  'Sex': ['male'],
                  

                      }

# %%
passengers_df = pd.DataFrame(Passenger_Data)

# %%
passengers_df
# Out:
#    PassengerId  Name   Sex
# 0          123  kola  male

# %%
tickets_Data = { 'PassengerId':[323],
                  'Ticket':[3.34567],
                  'Fare': [8.9456]
                      }

# %%
tickets_df = pd.DataFrame(tickets_Data)

# %%
tickets_df
# Out:
#    PassengerId   Ticket    Fare
# 0          323  3.34567  8.9456

# %%
#3.Merge these DataFrames on `PassengerId` using an inner join.

# %%
merged_df = pd.merge( passengers_df,tickets_df, on = 'PassengerId', how ='inner')

# %%
merged_df
# Out:
# Empty DataFrame
# Columns: [PassengerId, Name, Sex, Ticket, Fare]
# Index: []

# %%
#Task 2: Joining DataFrames
#1.From the Titanic dataset, create two DataFrames:
#`passenger_info` with columns: `Name`, `Sex`, indexed by `PassengerId`
#- `ticket_info` with columns: `Ticket`, `Fare`, indexed by `PassengerId`

# %%
passenger_info = Titanic_df[['PassengerId','Name', 'Sex']].set_index('PassengerId')
ticket_info = Titanic_df[['PassengerId','Ticket', 'Fare']].set_index('PassengerId')

# %%
print("passenger_info DataFrame:")
# Out:
# passenger_info DataFrame:

# %%
print(passenger_info.head())
# Out:
#                                                      Name     Sex
# PassengerId
# 892                                      Kelly, Mr. James    male
# 893                      Wilkes, Mrs. James (Ellen Needs)  female
# 894                             Myles, Mr. Thomas Francis    male
# 895                                      Wirz, Mr. Albert    male
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female

# %%
print("ticket_info' DataFrame:")
# Out:
# ticket_info' DataFrame:

# %%
print(ticket_info.head())
# Out:
#               Ticket     Fare
# PassengerId
# 892           330911   7.8292
# 893           363272   7.0000
# 894           240276   9.6875
# 895           315154   8.6625
# 896          3101298  12.2875

# %%
#2. Join these DataFrames on their indices using an inner join.
joined_df = passenger_info.join(ticket_info, how = 'inner')

# %%
joined_df
# Out:
#                                                      Name     Sex  \
# PassengerId
# 892                                      Kelly, Mr. James    male
# 893                      Wilkes, Mrs. James (Ellen Needs)  female
# 894                             Myles, Mr. Thomas Francis    male
# 895                                      Wirz, Mr. Albert    male
# 896          Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...                                                   ...     ...
# 1305                                   Spector, Mr. Woolf    male
# 1306                         Oliva y Ocana, Dona. Fermina  female
# 1307                         Saether, Mr. Simon Sivertsen    male
# 1308                                  Ware, Mr. Frederick    male
# 1309                             Peter, Master. Michael J    male
#
#                          Ticket      Fare
# PassengerId
# 892                      330911    7.8292
# 893                      363272    7.0000
# ...

# %%
#Task 3: Concatenating DataFrames

#1.Split the Titanic dataset into two DataFrames along columns:
    #- `part1` with columns: `PassengerId`, `Survived`, `Pclass`
    #- `part2` with columns: `Name`, `Sex`, `Age`

#2. Concatenate these DataFrames along columns (axis=1).

#Task 4: Appending DataFrames

# %%
part1 = Titanic_df[['PassengerId', 'Survived', 'Pclass']]
part2 = Titanic_df[['Name', 'Sex', 'Age']]

# %%
part1
# Out:
#      PassengerId  Survived  Pclass
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
# [418 rows x 3 columns]

# %%
part2
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
part1_part2 = pd.concat([part1, part2,])

# %%
part1_part2
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex   Age
# 0          892.0       0.0     3.0                           NaN     NaN   NaN
# 1          893.0       1.0     3.0                           NaN     NaN   NaN
# 2          894.0       0.0     2.0                           NaN     NaN   NaN
# 3          895.0       0.0     3.0                           NaN     NaN   NaN
# 4          896.0       1.0     3.0                           NaN     NaN   NaN
# ..           ...       ...     ...                           ...     ...   ...
# 413          NaN       NaN     NaN            Spector, Mr. Woolf    male   NaN
# 414          NaN       NaN     NaN  Oliva y Ocana, Dona. Fermina  female  39.0
# 415          NaN       NaN     NaN  Saether, Mr. Simon Sivertsen    male  38.5
# 416          NaN       NaN     NaN           Ware, Mr. Frederick    male   NaN
# 417          NaN       NaN     NaN      Peter, Master. Michael J    male   NaN
#
# [836 rows x 6 columns]

# %%
appended_df = pd.concat([part1,part2], axis=1)

# %%
print(appended_df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...
