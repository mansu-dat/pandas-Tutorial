# %%
import pandas as pd

# %%
cleaning = pd.read_excel('.//Presidents_DataSet.xlsx')

# %%
cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    47 non-null     int64
#  1   S.No.         47 non-null     int64
#  2   president     47 non-null     object
#  3   prior         47 non-null     object
#  4   party         47 non-null     object
#  5   vice          47 non-null     object
#  6   salary        47 non-null     int64
#  7   date updated  47 non-null     datetime64[ns]
#  8   date created  47 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 3.4+ KB

# %%
cleaning.head()
# Out:
#    Unnamed: 0  S.No.          president  \
# 0           0      1  George Washington
# 1           1      2         john adams
# 2           2      3   Thomas Jefferson
# 3           3      4      James Madison
# 4           4      5       JAMES MONROE
#
#                                                prior                    party  \
# 0  Commander-in-Chief  of the  Continental Army  ...              Nonpartisan
# 1           1st  Vice President of the United States               Federalist
# 2           2nd  Vice President of the United States  Democratic-  Republican
# 3  5th  United States Secretary of State   (1801â...  Democratic-  Republican
# 4  7th  United States Secretary of State   (1811â...  Democratic-  Republican
#
#                  vice  salary date updated date created
# 0          John Adams    5000   2021-07-14   2012-03-04
# 1    Thomas Jefferson   10000   2021-07-14   2012-03-04
# 2          Aaron Burr   15000   2021-07-14   2012-03-04
# ...

# %%
cleaning.tail()
# Out:
#     Unnamed: 0  S.No.       president  \
# 42          41     42    Bill Clinton
# 43          42     43  George W. Bush
# 44          43     44    Barack Obama
# 45          43     44    Barack Obama
# 46          44     45    Donald Trump
#
#                                                 prior        party  \
# 42  40th & 42nd  Governor of Arkansas   (1979â€“19...   Democratic
# 43          46th  Governor of Texas   ( 1995â€“2000 )   Republican
# 44  U.S. Senator   ( Class 3 )   from  Illinois   ...   Democratic
# 45  U.S. Senator   ( Class 3 )   from  Illinois   ...   Democratic
# 46  Chairman of   The Trump Organization   ( 1971â...  Republicans
#
#            vice  salary date updated date created
# 42      Al Gore  365000   2021-07-14   2012-03-04
# 43  Dick Cheney  375000   2021-07-14   2012-03-04
# 44    Joe Biden  395000   2021-07-14   2020-02-01
# 45    Joe Biden  395000   2021-07-14   2020-02-01
# 46   Mike Pence  405000   2021-07-14   2020-02-01

# %%
cleaning['party'].unique()
# Out:
# array(['Nonpartisan', 'Federalist', 'Democratic-  Republican',
#        'Democratic', 'Whig',
#        'Whig   April 4, 1841  â€“  September 13, 1841', 'Republican',
#        'Demorcatic', 'Republicans'], dtype=object)

# %%
# Nonpartisan, Federalist, Democratic-Republican, Democratic, Whiq, Republican

# %%
cleaning.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George Washington
# 1       2              john adams
# 2       3        Thomas Jefferson
# 3       4           James Madison
# 4       5            JAMES MONROE
# 5       6       John Quincy Adams
# 6       7          Andrew Jackson
# 7       8        Martin Van Buren
# 8       9  William Henry Harrison
# 9      10              john tyler
# 10     11           James K. Polk
# 11     12          Zachary Taylor
# 12     13        Millard Fillmore
# 13     14         Franklin Pierce
# 14     15          James Buchanan
# 15     16         Abraham Lincoln
# 16     17          Andrew Johnson
# 17     18        Ulysses S. Grant
# 18     19     Rutherford B. Hayes
# 19     20       James A. Garfield
# 20     21       Chester A. Arthur
# 21     22        Grover Cleveland
# 22     23       Benjamin Harrison
# 23     24        Grover Cleveland
# 24     25        William McKinley
# 25     26      Theodore Roosevelt
# ...

# %%
cleaning['president']= cleaning['president'].str.strip()

# %%
cleaning['president']= cleaning['president'].str.capitalize()

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
cleaning['prior']
# Out:
# 0     Commander-in-Chief  of the  Continental Army  ...
# 1              1st  Vice President of the United States
# 2              2nd  Vice President of the United States
# 3     5th  United States Secretary of State   (1801â...
# 4     7th  United States Secretary of State   (1811â...
# 5     8th  United States Secretary of State   (1817â...
# 6     U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 7              8th  Vice President of the United States
# 8     United States Minister to Colombia   (1828â€“1...
# 9             10th  Vice President of the United States
# 10           9th  Governor of Tennessee   (1839â€“1841)
# 11    Major General  of the  1st Infantry Regiment  ...
# 12            12th  Vice President of the United States
# 13    Brigadier General  of the  9th Infantry   Unit...
# 14    United States Minister  to the   Court of St J...
# 15    U.S. Representative  for  Illinois' 7th Distri...
# 16            16th  Vice President of the United States
# ...

# %%
cleaning['prior'].unique
# Out:
# <bound method Series.unique of 0     Commander-in-Chief  of the  Continental Army  ...
# 1              1st  Vice President of the United States
# 2              2nd  Vice President of the United States
# 3     5th  United States Secretary of State   (1801â...
# 4     7th  United States Secretary of State   (1811â...
# 5     8th  United States Secretary of State   (1817â...
# 6     U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 7              8th  Vice President of the United States
# 8     United States Minister to Colombia   (1828â€“1...
# 9             10th  Vice President of the United States
# 10           9th  Governor of Tennessee   (1839â€“1841)
# 11    Major General  of the  1st Infantry Regiment  ...
# 12            12th  Vice President of the United States
# 13    Brigadier General  of the  9th Infantry   Unit...
# 14    United States Minister  to the   Court of St J...
# 15    U.S. Representative  for  Illinois' 7th Distri...
# ...

# %%
cleaning['prior'] = cleaning['prior'].str.replace('â€“',' - ')

# %%
cleaning['prior'] = cleaning['prior'].str.strip()

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
Nonpartisan, Federalist, Democratic-Republican, Democratic, Whiq, Republican

# %%
cleaning['party'].unique()
# Out:
# array(['Nonpartisan', 'Federalist', 'Democratic-  Republican',
#        'Democratic', 'Whig',
#        'Whig   April 4, 1841  â€“  September 13, 1841', 'Republican',
#        'Demorcatic', 'Republicans'], dtype=object)

# %%
cleaning['party']=cleaning['party'].str.replace('Demorcatic','Democratic')
cleaning['party']=cleaning['party'].str.replace('Republicans','Republican')
cleaning['party']=cleaning['party'].str.replace('Whig   April 4, 1841  â€“  September 13, 1841','Whig')
cleaning['party']=cleaning['party'].str.replace('Democratic-  Republican','Democratic- Republican')

# %%
cleaning['party'].unique()
# Out:
# array(['Nonpartisan', 'Federalist', 'Democratic- Republican',
#        'Democratic', 'Whig', 'Republican'], dtype=object)

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
cleaning['vice']=cleaning['vice'].str.strip()

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
cleaning['firstName', 'Surname'] = cleaning['president'].str.split(' ')

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
cleaning.drop([('firstName','Surname')], axis=1, inplace=True)

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       George washington
# 1       2              John adams
# 2       3        Thomas jefferson
# 3       4           James madison
# 4       5            James monroe
# 5       6       John quincy adams
# 6       7          Andrew jackson
# 7       8        Martin van buren
# 8       9  William henry harrison
# 9      10              John tyler
# 10     11           James k. polk
# 11     12          Zachary taylor
# 12     13        Millard fillmore
# 13     14         Franklin pierce
# 14     15          James buchanan
# 15     16         Abraham lincoln
# 16     17          Andrew johnson
# 17     18        Ulysses s. grant
# 18     19     Rutherford b. hayes
# 19     20       James a. garfield
# 20     21       Chester a. arthur
# 21     22        Grover cleveland
# 22     23       Benjamin harrison
# 23     24        Grover cleveland
# 24     25        William mckinley
# 25     26      Theodore roosevelt
# ...

# %%
cleaning['firstName']= cleaning['president'].str.split(' ')

# %%
cleaning.drop([('firstName', 'secondName')], axis=1, inplace=True)

# %%
cleaning
# Out:
#     S.No.               president  \
# 0       1       GEORGE WASHINGTON
# 1       2              JOHN ADAMS
# 2       3        THOMAS JEFFERSON
# 3       4           JAMES MADISON
# 4       5            JAMES MONROE
# 5       6       JOHN QUINCY ADAMS
# 6       7          ANDREW JACKSON
# 7       8        MARTIN VAN BUREN
# 8       9  WILLIAM HENRY HARRISON
# 9      10              JOHN TYLER
# 10     11           JAMES K. POLK
# 11     12          ZACHARY TAYLOR
# 12     13        MILLARD FILLMORE
# 13     14         FRANKLIN PIERCE
# 14     15          JAMES BUCHANAN
# 15     16         ABRAHAM LINCOLN
# 16     17          ANDREW JOHNSON
# 17     18        ULYSSES S. GRANT
# 18     19     RUTHERFORD B. HAYES
# 19     20       JAMES A. GARFIELD
# 20     21       CHESTER A. ARTHUR
# 21     22        GROVER CLEVELAND
# 22     23       BENJAMIN HARRISON
# 23     24        GROVER CLEVELAND
# 24     25        WILLIAM MCKINLEY
# 25     26      THEODORE ROOSEVELT
# ...
