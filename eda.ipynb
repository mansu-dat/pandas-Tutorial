# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('.\Sample - Superstore.csv', encoding='latin1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.drop(columns='Row ID', inplace=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
rowAndColumns=df.shape
print('The dataset contain', rowAndColumns[0], 'rows and', rowAndColumns[1],'columns')
# Out:
# The dataset contain 9994 rows and 20 columns

# %% [markdown]
# ### Data Cleaning
#
# - Handle missing values appropriately
# - Check for duplicates and remove them if necessary
# - Convert relevant columns to appropriate data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   object
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
df.isna().sum()# isna can be subs with notna,notnull,isnull
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Using the .info() and .isna() function to check for missing values, it occurs that there is no missing value in the dataset.

# %% [markdown]
# ### Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID   Category Sub-Category  \
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df[df['Order ID']=='US-2014-150119']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
# 3407  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
# 3408  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3407  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3408  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID         Category Sub-Category  \
# 3405   East  FUR-CH-10002965        Furniture       Chairs
# 3406   East  FUR-CH-10002965        Furniture       Chairs
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# ####  Convert relevant columns to appropriate data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   object
#  2   Ship Date      9993 non-null   object
#  3   Ship Mode      9993 non-null   object
#  4   Customer ID    9993 non-null   object
#  5   Customer Name  9993 non-null   object
#  6   Segment        9993 non-null   object
#  7   Country        9993 non-null   object
#  8   City           9993 non-null   object
#  9   State          9993 non-null   object
#  10  Postal Code    9993 non-null   int64
#  11  Region         9993 non-null   object
#  12  Product ID     9993 non-null   object
#  13  Category       9993 non-null   object
#  14  Sub-Category   9993 non-null   object
#  15  Product Name   9993 non-null   object
#  16  Sales          9993 non-null   float64
# ...

# %% [markdown]
# Checking the datatypes of eachcolumns, we noticed that the OrderDate and ShipDate are not in their appropriate data type

# %%
df['Order Date']= pd.to_datetime(df['Order Date'])
df['Ship Date']= pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### Exploratory Data Analysis (EDA):
#
#
# -Explore the distribution over time.
#
# -Analyze the top- sellingproducts.
#
# -Investigate the relationship between quantity sold and revenue.
#
# -Identify any trends or patterns in customer behaviour

# %%
saless_over_time= df.groupby(df['Order Date'].dt.year)['Sales'].sum()# .dt.year is added to the code to get exact years

# %%
saless_over_time
# Out:
# Order Date
# 2014    483966.1261
# 2015    470532.5090
# 2016    609205.5980
# 2017    733215.2552
# Name: Sales, dtype: float64

# %%
plt.figure(figsize= (8, 4))
saless_over_time.plot(kind='line', color='skyblue', marker= 'o')
plt.title('Distribution of Sales over time')
plt.xlabel('Year')
plt.ylabel('Sales over Time')

plt.xticks(saless_over_time.index.astype(int))
plt.grid(True)

# %%
top_sale_product= df.groupby('Product Name')['Sales'].sum().reset_index()

# %%
top_sale_product
# Out:
#                                            Product Name     Sales
# 0     "While you Were Out" Message Book, One Form pe...    25.228
# 1              #10 Gummed Flap White Envelopes, 100/Box    41.300
# 2                         #10 Self-Seal White Envelopes   108.682
# 3            #10 White Business Envelopes,4 1/8 x 9 1/2   488.904
# 4               #10- 4 1/8" x 9 1/2" Recycled Envelopes   286.672
# ...                                                 ...       ...
# 1845  iKross Bluetooth Portable Keyboard + Cell Phon...   477.660
# 1846                         iOttie HLCRIO102 Car Mount   215.892
# 1847                                iOttie XL Car Mount   223.888
# 1848  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...   442.554
# 1849                 netTALK DUO VoIP Telephone Service  1112.788
#
# [1850 rows x 2 columns]

# %%
top_sale_product=top_sale_product.sort_values(by='Sales',ascending = False)
top_n = 10
top_product =top_sale_product.head(top_n)
top_product
# Out:
#                                           Product Name      Sales
# 404              Canon imageCLASS 2200 Advanced Copier  61599.824
# 650  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 444  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 786       HON 5400 Series Task Chairs for Big and Tall  21870.576
# 686         GBC DocuBind TL300 Electric Binding System  19823.479
# 688   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 805               Hewlett Packard LaserJet 3310 Copier  18839.686
# 787  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 683          GBC DocuBind P400 Electric Binding System  17965.068
# 813        High Speed Automatic Electric Letter Opener  17030.312

# %%
plt.figure(figsize= (8, 4))
# top_product.plot(kind='bar',x='Sales', y='Product Name', color='skyblue')
top_product.plot(kind='bar', x='Product Name',y='Sales')
plt.title('top selling product')
plt.xlabel=('Sales')
plt.ylabel=('Global Sales(in Millions)')
plt.grid(True);

# %%
top_product.plot(kind='hist', x='Product Name',y='Sales')
plt.title('top selling product')
plt.xlabel=('Sales')
plt.ylabel=('Global Sales(in millions)')
plt.grid(True);

# %%
#As the dataset didn't include the revenue column. I will have to calculate it
df['Revenue'] = df['Quantity'] * df['Sales']

# %%
#Investigate the relationship between quantity sold and revenue.
plt.figure(figsize=(14,6))
plt.scatter(df['Quantity'], df['Revenue'], alpha=0.5)
plt.title("Relationship Between Quantity Sold and Revenue")
plt.xlabel('Quantity Sold')
plt.ylabelRevenue
plt.gridTrue
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       3 plt.scatter(df['Quantity'], df['Revenue'], alpha=0.5)
#       4 plt.title("Relationship Between Quantity Sold and Revenue")
# ----> 5 plt.xlabel('Quantity Sold')
#       6 plt.ylabelRevenue
#       7 plt.gridTrue
#
# TypeError: 'str' object is not callable

# %%
#Group by discount level and calculate average revenue and quantity sold
discount_analysis = df.groupby('Discount').agg({
    'Revenue': 'mean',
    'Quantity': 'sum'
}).reset_index()
discount_analysis
# Out:
#     Discount      Revenue  Quantity
# 0       0.00  1154.334175     18267
# 1       0.10  3320.590309       373
# 2       0.15  2819.752894       198
# 3       0.20  1004.986076     13660
# 4       0.30  2117.321748       847
# 5       0.32  2762.332015       105
# 6       0.40  3025.157243       786
# 7       0.45  2255.343000        45
# 8       0.50  4386.279545       241
# 9       0.60   225.182232       501
# 10      0.70   489.816861      1660
# 11      0.80   295.351160      1188

# %%
# Plot the impact of different discount levels on average revenue
plt.figure(figsize=(10, 6))
plt.bar(discount_analysis['Discount'], discount_analysis['Revenue'], color='skyblue')
plt.title('Discount Analysis: Impact on Average Revenue')
plt.xlabel('Discount Level')
plt.ylabel('Average Revenue per Transaction')
plt.grid(axis='y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 5
#       3 plt.bar(discount_analysis['Discount'], discount_analysis['Revenue'], color='skyblue')
#       4 plt.title('Discount Analysis: Impact on Average Revenue')
# ----> 5 plt.xlabel('Discount Level')
#       6 plt.ylabel('Average Revenue per Transaction')
#       7 plt.grid(axis='y')
#
# TypeError: 'str' object is not callable

# %%
df['Sales']=df['Sales'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9993 non-null   object
#  1   Order Date     9993 non-null   datetime64[ns]
#  2   Ship Date      9993 non-null   datetime64[ns]
#  3   Ship Mode      9993 non-null   object
#  4   Customer ID    9993 non-null   object
#  5   Customer Name  9993 non-null   object
#  6   Segment        9993 non-null   object
#  7   Country        9993 non-null   object
#  8   City           9993 non-null   object
#  9   State          9993 non-null   object
#  10  Postal Code    9993 non-null   int64
#  11  Region         9993 non-null   object
#  12  Product ID     9993 non-null   object
#  13  Category       9993 non-null   object
#  14  Sub-Category   9993 non-null   object
#  15  Product Name   9993 non-null   object
#  16  Sales          9993 non-null   object
# ...

# %%
sales_for_each_city = df.groupby('City')['Sales'].sum().reset_index()
sales_for_each_city
# Out:
#             City     Sales
# 0       Aberdeen    25.500
# 1        Abilene     1.392
# 2          Akron  2729.986
# 3    Albuquerque  2220.160
# 4     Alexandria  5519.570
# ..           ...       ...
# 526   Woonsocket   195.550
# 527      Yonkers  7657.666
# 528         York   817.978
# 529      Yucaipa    50.800
# 530         Yuma   840.865
#
# [531 rows x 2 columns]

# %%
top_city_sales = sales_for_each_city.sort_values(by='Sales', ascending=False)
top_city_sales
# Out:
#               City       Sales
# 329  New York City  256368.161
# 266    Los Angeles  175851.341
# 452        Seattle  119540.742
# 438  San Francisco  112669.092
# 374   Philadelphia  109077.013
# ..             ...         ...
# 354   Ormond Beach       2.808
# 370      Pensacola       2.214
# 221        Jupiter       2.064
# 140         Elyria       1.824
# 1          Abilene       1.392
#
# [531 rows x 2 columns]

# %%
top_city = top_city_sales.head(top_n)
top_city
# Out:
#               City        Sales
# 329  New York City  256368.1610
# 266    Los Angeles  175851.3410
# 452        Seattle  119540.7420
# 438  San Francisco  112669.0920
# 374   Philadelphia  109077.0130
# 207        Houston   64504.7604
# 80         Chicago   48539.5410
# 437      San Diego   47521.0290
# 216   Jacksonville   44713.1830
# 464    Springfield   43054.3420

# %%
plt.figure(figsize=(14,6))
plt.bar(top_city['City'], top_city['Sales'], color='purple')
plt.title('Cities Leading in Total Sales')
plt.xlabel['Cities']
plt.ylabel('Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 4
#       2 plt.bar(top_city['City'], top_city['Sales'], color='purple')
#       3 plt.title('Cities Leading in Total Sales')
# ----> 4 plt.xlabel['Cities']
#       5 plt.ylabel('Sales')
#       6 plt.show()
#
# TypeError: string indices must be integers, not 'str'

# %%
sales_for_each_day = df.groupby(df['Order Date'].dt.strftime('%A')
)['Sales'].sum().reset_index()
sales_for_each_day.sort_values(by='Order Date', inplace=True)
sales_for_each_day
# Out:
#   Order Date        Sales
# 0     Friday  427692.2593
# 1     Monday  428937.8157
# 2   Saturday  357984.6830
# 3     Sunday  385353.8464
# 4   Thursday  321965.7785
# 5    Tuesday  287209.5022
# 6  Wednesday   87775.6032

# %%
plt.figure(figsize=(14,6))
sales_for_each_day.plot(kind='bar', x='Order Date', y='Sales')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 plt.figure(figsize=(14,6))
#       2 sales_for_each_day.plot(kind='bar', x='Order Date', y='Sales')
# ----> 3 plt.xlabel('Day')
#       4 plt.ylabel('Sales')
#       5 plt.show()
#
# TypeError: 'str' object is not callable
